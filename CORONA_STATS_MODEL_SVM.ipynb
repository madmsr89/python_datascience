# %% [markdown]
# **Import Libararies**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Import data to the process**

# %%
dataset = pd.read_csv('CORONA_TN_DATA.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

print(X)

# %%
y = y.reshape(len(y),1)
print(y)

# %% [markdown]
# **Use Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X)
y= sc_y.fit_transform(y)
print(X)
print(y)

# %% [markdown]
# **Implement the Linear Regression Model for Test case and Positive Ratio**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X, y)

# %% [markdown]
# **Use Support Vector Features**

# %%
from sklearn.svm import SVR
sv_reg = SVR(kernel = 'rbf')
sv_reg.fit(X, y)

# %% [markdown]
# **Predict Using SVM**

# %%
sc_y.inverse_transform(sv_reg.predict(sc_X.transform([[120000]])))
# Out:
# array([11285.78023749])

# %% [markdown]
# **Predict and Plot with SVM Regression**

# %%
X_grid = np.arange(min(sc_X.inverse_transform(X)), max(sc_X.inverse_transform(X)), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(sc_X.inverse_transform(X), sc_y.inverse_transform(y), color = 'red')
plt.plot(X_grid, sc_y.inverse_transform(sv_reg.predict(sc_X.transform(X_grid))), color = 'blue')
plt.title('Corona Tests vs Positive data(Training set)')
plt.xlabel('Number of tests')
plt.ylabel('Number of Positives')
plt.show()

# %%
print(dataset)
# Out:
#     day_interval  tests_conducted  tests_postive
# 0              7               35              0
# 1             14              454              8
# 2             21             1488             58
# 3             28             2975            554
# 4             35             7731            552
# 5             42            28130            304
# 6             49            46729            408
# 7             56            62502           1138
# 8             63            92930           4181
# 9             70            83683           4020
# 10            77            82895           5053
# 11            84            82347           6056
# 12            91           101008           9334
# 13            98           117629          12994
# 14           105           182013          14716
